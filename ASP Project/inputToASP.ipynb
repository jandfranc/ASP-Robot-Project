# %%
import numpy as np

# %%
def initAnswerSet(size = [5,5]):
#im dumb and columns and rows are the wrong way around
    i_row = size[0]
    i_col = size[1]
    i = -1
    array = np.empty(size, dtype='object')
    
    ASPInput = []

    for n_row in range(i_row):
        for n_col in range(i_col):
            i+=1
            array[n_row][n_col] = f'x{i}'
            
    for n_row in range(i_row):
        for n_col in range(i_col):
            if n_row == 0 and n_col == 0:
              ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row+1,n_col]}),0).') 
              ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row,n_col+1]}),0).')
                
            elif n_row == 0 and n_col == i_col-1:
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row+1,n_col]}),0).') 
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row,n_col-1]}),0).')
                
            elif n_row == i_row-1 and n_col == 0:
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row-1,n_col]}),0).') 
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row,n_col+1]}),0).')
                
            elif n_row == i_row-1 and n_col == i_col-1:
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row-1,n_col]}),0).') 
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row,n_col-1]}),0).')
            
            elif n_row == 0:
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row+1,n_col]}),0).') 
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row,n_col+1]}),0).')
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row,n_col-1]}),0).') 
            
            elif n_col == 0:
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row+1,n_col]}),0).') 
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row,n_col+1]}),0).')
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row-1,n_col]}),0).') 
            
            elif n_row == i_row-1:
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row-1,n_col]}),0).') 
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row,n_col+1]}),0).')
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row,n_col-1]}),0).')
            
            elif n_col == i_col-1:
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row+1,n_col]}),0).') 
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row,n_col-1]}),0).')
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row-1,n_col]}),0).') 
            
            else:
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row+1,n_col]}),0).') 
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row,n_col+1]}),0).')
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row,n_col-1]}),0).')
                ASPInput.append(f'holds(adjacent({array[n_row,n_col]}, {array[n_row-1,n_col]}),0).')
    return ASPInput

# %%
a = initAnswerSet([100,1000])

# %%
a
# Out:
# ['holds(adjacent(x0, x1000),0).',
#  'holds(adjacent(x0, x1),0).',
#  'holds(adjacent(x1, x1001),0).',
#  'holds(adjacent(x1, x2),0).',
#  'holds(adjacent(x1, x0),0).',
#  'holds(adjacent(x2, x1002),0).',
#  'holds(adjacent(x2, x3),0).',
#  'holds(adjacent(x2, x1),0).',
#  'holds(adjacent(x3, x1003),0).',
#  'holds(adjacent(x3, x4),0).',
#  'holds(adjacent(x3, x2),0).',
#  'holds(adjacent(x4, x1004),0).',
#  'holds(adjacent(x4, x5),0).',
#  'holds(adjacent(x4, x3),0).',
#  'holds(adjacent(x5, x1005),0).',
#  'holds(adjacent(x5, x6),0).',
#  'holds(adjacent(x5, x4),0).',
#  'holds(adjacent(x6, x1006),0).',
#  'holds(adjacent(x6, x7),0).',
#  'holds(adjacent(x6, x5),0).',
#  'holds(adjacent(x7, x1007),0).',
#  'holds(adjacent(x7, x8),0).',
#  'holds(adjacent(x7, x6),0).',
#  'holds(adjacent(x8, x1008),0).',
#  'holds(adjacent(x8, x9),0).',
#  'holds(adjacent(x8, x7),0).',
#  'holds(adjacent(x9, x1009),0).',
#  'holds(adjacent(x9, x10),0).',
#  'holds(adjacent(x9, x8),0).',
#  'holds(adjacent(x10, x1010),0).',
#  'holds(adjacent(x10, x11),0).',
#  'holds(adjacent(x10, x9),0).',
#  'holds(adjacent(x11, x1011),0).',
#  'holds(adjacent(x11, x12),0).',
#  'holds(adjacent(x11, x10),0).',
#  'holds(adjacent(x12, x1012),0).',
#  'holds(adjacent(x12, x13),0).',
#  'holds(adjacent(x12, x11),0).',
#  'holds(adjacent(x13, x1013),0).',
#  'holds(adjacent(x13, x14),0).',
#  'holds(adjacent(x13, x12),0).',
#  'holds(adjacent(x14, x1014),0).',
#  'holds(adjacent(x14, x15),0).',
#  'holds(adjacent(x14, x13),0).',
#  'holds(adjacent(x15, x1015),0).',
#  'holds(adjacent(x15, x16),0).',
#  'holds(adjacent(x15, x14),0).',
#  'holds(adjacent(x16, x1016),0).',
#  'holds(adjacent(x16, x17),0).',
#  'holds(adjacent(x16, x15),0).',
#  'holds(adjacent(x17, x1017),0).',
#  'holds(adjacent(x17, x18),0).',
#  'holds(adjacent(x17, x16),0).',
#  'holds(adjacent(x18, x1018),0).',
#  'holds(adjacent(x18, x19),0).',
#  'holds(adjacent(x18, x17),0).',
#  'holds(adjacent(x19, x1019),0).',
#  'holds(adjacent(x19, x20),0).',
#  'holds(adjacent(x19, x18),0).',
#  'holds(adjacent(x20, x1020),0).',
#  'holds(adjacent(x20, x21),0).',
#  'holds(adjacent(x20, x19),0).',
#  'holds(adjacent(x21, x1021),0).',
#  'holds(adjacent(x21, x22),0).',
#  'holds(adjacent(x21, x20),0).',
#  'holds(adjacent(x22, x1022),0).',
#  'holds(adjacent(x22, x23),0).',
#  'holds(adjacent(x22, x21),0).',
#  'holds(adjacent(x23, x1023),0).',
#  'holds(adjacent(x23, x24),0).',
#  'holds(adjacent(x23, x22),0).',
#  'holds(adjacent(x24, x1024),0).',
#  'holds(adjacent(x24, x25),0).',
#  'holds(adjacent(x24, x23),0).',
#  'holds(adjacent(x25, x1025),0).',
#  'holds(adjacent(x25, x26),0).',
#  'holds(adjacent(x25, x24),0).',
#  'holds(adjacent(x26, x1026),0).',
#  'holds(adjacent(x26, x27),0).',
#  'holds(adjacent(x26, x25),0).',
#  'holds(adjacent(x27, x1027),0).',
#  'holds(adjacent(x27, x28),0).',
#  'holds(adjacent(x27, x26),0).',
#  'holds(adjacent(x28, x1028),0).',
#  'holds(adjacent(x28, x29),0).',
#  'holds(adjacent(x28, x27),0).',
#  'holds(adjacent(x29, x1029),0).',
#  'holds(adjacent(x29, x30),0).',
#  'holds(adjacent(x29, x28),0).',
#  'holds(adjacent(x30, x1030),0).',
#  'holds(adjacent(x30, x31),0).',
#  'holds(adjacent(x30, x29),0).',
#  'holds(adjacent(x31, x1031),0).',
#  'holds(adjacent(x31, x32),0).',
#  'holds(adjacent(x31, x30),0).',
#  'holds(adjacent(x32, x1032),0).',
#  'holds(adjacent(x32, x33),0).',
#  'holds(adjacent(x32, x31),0).',
#  'holds(adjacent(x33, x1033),0).',
#  'holds(adjacent(x33, x34),0).',
#  'holds(adjacent(x33, x32),0).',
#  'holds(adjacent(x34, x1034),0).',
#  'holds(adjacent(x34, x35),0).',
#  'holds(adjacent(x34, x33),0).',
#  'holds(adjacent(x35, x1035),0).',
#  'holds(adjacent(x35, x36),0).',
#  'holds(adjacent(x35, x34),0).',
#  'holds(adjacent(x36, x1036),0).',
#  'holds(adjacent(x36, x37),0).',
#  'holds(adjacent(x36, x35),0).',
#  'holds(adjacent(x37, x1037),0).',
#  'holds(adjacent(x37, x38),0).',
#  'holds(adjacent(x37, x36),0).',
#  'holds(adjacent(x38, x1038),0).',
#  'holds(adjacent(x38, x39),0).',
#  'holds(adjacent(x38, x37),0).',
#  'holds(adjacent(x39, x1039),0).',
#  'holds(adjacent(x39, x40),0).',
#  'holds(adjacent(x39, x38),0).',
#  'holds(adjacent(x40, x1040),0).',
#  'holds(adjacent(x40, x41),0).',
#  'holds(adjacent(x40, x39),0).',
#  'holds(adjacent(x41, x1041),0).',
#  'holds(adjacent(x41, x42),0).',
#  'holds(adjacent(x41, x40),0).',
#  'holds(adjacent(x42, x1042),0).',
#  'holds(adjacent(x42, x43),0).',
#  'holds(adjacent(x42, x41),0).',
#  'holds(adjacent(x43, x1043),0).',
#  'holds(adjacent(x43, x44),0).',
#  'holds(adjacent(x43, x42),0).',
#  'holds(adjacent(x44, x1044),0).',
#  'holds(adjacent(x44, x45),0).',
#  'holds(adjacent(x44, x43),0).',
#  'holds(adjacent(x45, x1045),0).',
#  'holds(adjacent(x45, x46),0).',
#  'holds(adjacent(x45, x44),0).',
#  'holds(adjacent(x46, x1046),0).',
#  'holds(adjacent(x46, x47),0).',
#  'holds(adjacent(x46, x45),0).',
#  'holds(adjacent(x47, x1047),0).',
#  'holds(adjacent(x47, x48),0).',
#  'holds(adjacent(x47, x46),0).',
#  'holds(adjacent(x48, x1048),0).',
#  'holds(adjacent(x48, x49),0).',
#  'holds(adjacent(x48, x47),0).',
#  'holds(adjacent(x49, x1049),0).',
#  'holds(adjacent(x49, x50),0).',
#  'holds(adjacent(x49, x48),0).',
#  'holds(adjacent(x50, x1050),0).',
#  'holds(adjacent(x50, x51),0).',
#  'holds(adjacent(x50, x49),0).',
#  'holds(adjacent(x51, x1051),0).',
#  'holds(adjacent(x51, x52),0).',
#  'holds(adjacent(x51, x50),0).',
#  'holds(adjacent(x52, x1052),0).',
#  'holds(adjacent(x52, x53),0).',
#  'holds(adjacent(x52, x51),0).',
#  'holds(adjacent(x53, x1053),0).',
#  'holds(adjacent(x53, x54),0).',
#  'holds(adjacent(x53, x52),0).',
#  'holds(adjacent(x54, x1054),0).',
#  'holds(adjacent(x54, x55),0).',
#  'holds(adjacent(x54, x53),0).',
#  'holds(adjacent(x55, x1055),0).',
#  'holds(adjacent(x55, x56),0).',
#  'holds(adjacent(x55, x54),0).',
#  'holds(adjacent(x56, x1056),0).',
#  'holds(adjacent(x56, x57),0).',
#  'holds(adjacent(x56, x55),0).',
#  'holds(adjacent(x57, x1057),0).',
#  'holds(adjacent(x57, x58),0).',
#  'holds(adjacent(x57, x56),0).',
#  'holds(adjacent(x58, x1058),0).',
#  'holds(adjacent(x58, x59),0).',
#  'holds(adjacent(x58, x57),0).',
#  'holds(adjacent(x59, x1059),0).',
#  'holds(adjacent(x59, x60),0).',
#  'holds(adjacent(x59, x58),0).',
#  'holds(adjacent(x60, x1060),0).',
#  'holds(adjacent(x60, x61),0).',
#  'holds(adjacent(x60, x59),0).',
#  'holds(adjacent(x61, x1061),0).',
#  'holds(adjacent(x61, x62),0).',
#  'holds(adjacent(x61, x60),0).',
#  'holds(adjacent(x62, x1062),0).',
#  'holds(adjacent(x62, x63),0).',
#  'holds(adjacent(x62, x61),0).',
#  'holds(adjacent(x63, x1063),0).',
#  'holds(adjacent(x63, x64),0).',
#  'holds(adjacent(x63, x62),0).',
#  'holds(adjacent(x64, x1064),0).',
#  'holds(adjacent(x64, x65),0).',
#  'holds(adjacent(x64, x63),0).',
#  'holds(adjacent(x65, x1065),0).',
#  'holds(adjacent(x65, x66),0).',
#  'holds(adjacent(x65, x64),0).',
#  'holds(adjacent(x66, x1066),0).',
#  'holds(adjacent(x66, x67),0).',
#  'holds(adjacent(x66, x65),0).',
#  'holds(adjacent(x67, x1067),0).',
#  'holds(adjacent(x67, x68),0).',
#  'holds(adjacent(x67, x66),0).',
#  'holds(adjacent(x68, x1068),0).',
#  'holds(adjacent(x68, x69),0).',
#  'holds(adjacent(x68, x67),0).',
#  'holds(adjacent(x69, x1069),0).',
#  'holds(adjacent(x69, x70),0).',
#  'holds(adjacent(x69, x68),0).',
#  'holds(adjacent(x70, x1070),0).',
#  'holds(adjacent(x70, x71),0).',
#  'holds(adjacent(x70, x69),0).',
#  'holds(adjacent(x71, x1071),0).',
#  'holds(adjacent(x71, x72),0).',
#  'holds(adjacent(x71, x70),0).',
#  'holds(adjacent(x72, x1072),0).',
#  'holds(adjacent(x72, x73),0).',
#  'holds(adjacent(x72, x71),0).',
#  'holds(adjacent(x73, x1073),0).',
#  'holds(adjacent(x73, x74),0).',
#  'holds(adjacent(x73, x72),0).',
#  'holds(adjacent(x74, x1074),0).',
#  'holds(adjacent(x74, x75),0).',
#  'holds(adjacent(x74, x73),0).',
#  'holds(adjacent(x75, x1075),0).',
#  'holds(adjacent(x75, x76),0).',
#  'holds(adjacent(x75, x74),0).',
#  'holds(adjacent(x76, x1076),0).',
#  'holds(adjacent(x76, x77),0).',
#  'holds(adjacent(x76, x75),0).',
#  'holds(adjacent(x77, x1077),0).',
#  'holds(adjacent(x77, x78),0).',
#  'holds(adjacent(x77, x76),0).',
#  'holds(adjacent(x78, x1078),0).',
#  'holds(adjacent(x78, x79),0).',
#  'holds(adjacent(x78, x77),0).',
#  'holds(adjacent(x79, x1079),0).',
#  'holds(adjacent(x79, x80),0).',
#  'holds(adjacent(x79, x78),0).',
#  'holds(adjacent(x80, x1080),0).',
#  'holds(adjacent(x80, x81),0).',
#  'holds(adjacent(x80, x79),0).',
#  'holds(adjacent(x81, x1081),0).',
#  'holds(adjacent(x81, x82),0).',
#  'holds(adjacent(x81, x80),0).',
#  'holds(adjacent(x82, x1082),0).',
#  'holds(adjacent(x82, x83),0).',
#  'holds(adjacent(x82, x81),0).',
#  'holds(adjacent(x83, x1083),0).',
#  'holds(adjacent(x83, x84),0).',
#  'holds(adjacent(x83, x82),0).',
#  'holds(adjacent(x84, x1084),0).',
#  'holds(adjacent(x84, x85),0).',
#  'holds(adjacent(x84, x83),0).',
#  'holds(adjacent(x85, x1085),0).',
#  'holds(adjacent(x85, x86),0).',
#  'holds(adjacent(x85, x84),0).',
#  'holds(adjacent(x86, x1086),0).',
#  'holds(adjacent(x86, x87),0).',
#  'holds(adjacent(x86, x85),0).',
#  'holds(adjacent(x87, x1087),0).',
#  'holds(adjacent(x87, x88),0).',
#  'holds(adjacent(x87, x86),0).',
#  'holds(adjacent(x88, x1088),0).',
#  'holds(adjacent(x88, x89),0).',
#  'holds(adjacent(x88, x87),0).',
#  'holds(adjacent(x89, x1089),0).',
#  'holds(adjacent(x89, x90),0).',
#  'holds(adjacent(x89, x88),0).',
#  'holds(adjacent(x90, x1090),0).',
#  'holds(adjacent(x90, x91),0).',
#  'holds(adjacent(x90, x89),0).',
#  'holds(adjacent(x91, x1091),0).',
#  'holds(adjacent(x91, x92),0).',
#  'holds(adjacent(x91, x90),0).',
#  'holds(adjacent(x92, x1092),0).',
#  'holds(adjacent(x92, x93),0).',
#  'holds(adjacent(x92, x91),0).',
#  'holds(adjacent(x93, x1093),0).',
#  'holds(adjacent(x93, x94),0).',
#  'holds(adjacent(x93, x92),0).',
#  'holds(adjacent(x94, x1094),0).',
#  'holds(adjacent(x94, x95),0).',
#  'holds(adjacent(x94, x93),0).',
#  'holds(adjacent(x95, x1095),0).',
#  'holds(adjacent(x95, x96),0).',
#  'holds(adjacent(x95, x94),0).',
#  'holds(adjacent(x96, x1096),0).',
#  'holds(adjacent(x96, x97),0).',
#  'holds(adjacent(x96, x95),0).',
#  'holds(adjacent(x97, x1097),0).',
#  'holds(adjacent(x97, x98),0).',
#  'holds(adjacent(x97, x96),0).',
#  'holds(adjacent(x98, x1098),0).',
#  'holds(adjacent(x98, x99),0).',
#  'holds(adjacent(x98, x97),0).',
#  'holds(adjacent(x99, x1099),0).',
#  'holds(adjacent(x99, x100),0).',
#  'holds(adjacent(x99, x98),0).',
#  'holds(adjacent(x100, x1100),0).',
#  'holds(adjacent(x100, x101),0).',
#  'holds(adjacent(x100, x99),0).',
#  'holds(adjacent(x101, x1101),0).',
#  'holds(adjacent(x101, x102),0).',
#  'holds(adjacent(x101, x100),0).',
#  'holds(adjacent(x102, x1102),0).',
#  'holds(adjacent(x102, x103),0).',
#  'holds(adjacent(x102, x101),0).',
#  'holds(adjacent(x103, x1103),0).',
#  'holds(adjacent(x103, x104),0).',
#  'holds(adjacent(x103, x102),0).',
#  'holds(adjacent(x104, x1104),0).',
#  'holds(adjacent(x104, x105),0).',
#  'holds(adjacent(x104, x103),0).',
#  'holds(adjacent(x105, x1105),0).',
#  'holds(adjacent(x105, x106),0).',
#  'holds(adjacent(x105, x104),0).',
#  'holds(adjacent(x106, x1106),0).',
#  'holds(adjacent(x106, x107),0).',
#  'holds(adjacent(x106, x105),0).',
#  'holds(adjacent(x107, x1107),0).',
#  'holds(adjacent(x107, x108),0).',
#  'holds(adjacent(x107, x106),0).',
#  'holds(adjacent(x108, x1108),0).',
#  'holds(adjacent(x108, x109),0).',
#  'holds(adjacent(x108, x107),0).',
#  'holds(adjacent(x109, x1109),0).',
#  'holds(adjacent(x109, x110),0).',
#  'holds(adjacent(x109, x108),0).',
#  'holds(adjacent(x110, x1110),0).',
#  'holds(adjacent(x110, x111),0).',
#  'holds(adjacent(x110, x109),0).',
#  'holds(adjacent(x111, x1111),0).',
#  'holds(adjacent(x111, x112),0).',
#  'holds(adjacent(x111, x110),0).',
#  'holds(adjacent(x112, x1112),0).',
#  'holds(adjacent(x112, x113),0).',
#  'holds(adjacent(x112, x111),0).',
#  'holds(adjacent(x113, x1113),0).',
#  'holds(adjacent(x113, x114),0).',
#  'holds(adjacent(x113, x112),0).',
#  'holds(adjacent(x114, x1114),0).',
#  'holds(adjacent(x114, x115),0).',
#  'holds(adjacent(x114, x113),0).',
#  'holds(adjacent(x115, x1115),0).',
#  'holds(adjacent(x115, x116),0).',
#  'holds(adjacent(x115, x114),0).',
#  'holds(adjacent(x116, x1116),0).',
#  'holds(adjacent(x116, x117),0).',
#  'holds(adjacent(x116, x115),0).',
#  'holds(adjacent(x117, x1117),0).',
#  'holds(adjacent(x117, x118),0).',
#  'holds(adjacent(x117, x116),0).',
#  'holds(adjacent(x118, x1118),0).',
#  'holds(adjacent(x118, x119),0).',
#  'holds(adjacent(x118, x117),0).',
#  'holds(adjacent(x119, x1119),0).',
#  'holds(adjacent(x119, x120),0).',
#  'holds(adjacent(x119, x118),0).',
#  'holds(adjacent(x120, x1120),0).',
#  'holds(adjacent(x120, x121),0).',
#  'holds(adjacent(x120, x119),0).',
#  'holds(adjacent(x121, x1121),0).',
#  'holds(adjacent(x121, x122),0).',
#  'holds(adjacent(x121, x120),0).',
#  'holds(adjacent(x122, x1122),0).',
#  'holds(adjacent(x122, x123),0).',
#  'holds(adjacent(x122, x121),0).',
#  'holds(adjacent(x123, x1123),0).',
#  'holds(adjacent(x123, x124),0).',
#  'holds(adjacent(x123, x122),0).',
#  'holds(adjacent(x124, x1124),0).',
#  'holds(adjacent(x124, x125),0).',
#  'holds(adjacent(x124, x123),0).',
#  'holds(adjacent(x125, x1125),0).',
#  'holds(adjacent(x125, x126),0).',
#  'holds(adjacent(x125, x124),0).',
#  'holds(adjacent(x126, x1126),0).',
#  'holds(adjacent(x126, x127),0).',
#  'holds(adjacent(x126, x125),0).',
#  'holds(adjacent(x127, x1127),0).',
#  'holds(adjacent(x127, x128),0).',
#  'holds(adjacent(x127, x126),0).',
#  'holds(adjacent(x128, x1128),0).',
#  'holds(adjacent(x128, x129),0).',
#  'holds(adjacent(x128, x127),0).',
#  'holds(adjacent(x129, x1129),0).',
#  'holds(adjacent(x129, x130),0).',
#  'holds(adjacent(x129, x128),0).',
#  'holds(adjacent(x130, x1130),0).',
#  'holds(adjacent(x130, x131),0).',
#  'holds(adjacent(x130, x129),0).',
#  'holds(adjacent(x131, x1131),0).',
#  'holds(adjacent(x131, x132),0).',
#  'holds(adjacent(x131, x130),0).',
#  'holds(adjacent(x132, x1132),0).',
#  'holds(adjacent(x132, x133),0).',
#  'holds(adjacent(x132, x131),0).',
#  'holds(adjacent(x133, x1133),0).',
#  'holds(adjacent(x133, x134),0).',
#  'holds(adjacent(x133, x132),0).',
#  'holds(adjacent(x134, x1134),0).',
#  'holds(adjacent(x134, x135),0).',
#  'holds(adjacent(x134, x133),0).',
#  'holds(adjacent(x135, x1135),0).',
#  'holds(adjacent(x135, x136),0).',
#  'holds(adjacent(x135, x134),0).',
#  'holds(adjacent(x136, x1136),0).',
#  'holds(adjacent(x136, x137),0).',
#  'holds(adjacent(x136, x135),0).',
#  'holds(adjacent(x137, x1137),0).',
#  'holds(adjacent(x137, x138),0).',
#  'holds(adjacent(x137, x136),0).',
#  'holds(adjacent(x138, x1138),0).',
#  'holds(adjacent(x138, x139),0).',
#  'holds(adjacent(x138, x137),0).',
#  'holds(adjacent(x139, x1139),0).',
#  'holds(adjacent(x139, x140),0).',
#  'holds(adjacent(x139, x138),0).',
#  'holds(adjacent(x140, x1140),0).',
#  'holds(adjacent(x140, x141),0).',
#  'holds(adjacent(x140, x139),0).',
#  'holds(adjacent(x141, x1141),0).',
#  'holds(adjacent(x141, x142),0).',
#  'holds(adjacent(x141, x140),0).',
#  'holds(adjacent(x142, x1142),0).',
#  'holds(adjacent(x142, x143),0).',
#  'holds(adjacent(x142, x141),0).',
#  'holds(adjacent(x143, x1143),0).',
#  'holds(adjacent(x143, x144),0).',
#  'holds(adjacent(x143, x142),0).',
#  'holds(adjacent(x144, x1144),0).',
#  'holds(adjacent(x144, x145),0).',
#  'holds(adjacent(x144, x143),0).',
#  'holds(adjacent(x145, x1145),0).',
#  'holds(adjacent(x145, x146),0).',
#  'holds(adjacent(x145, x144),0).',
#  'holds(adjacent(x146, x1146),0).',
#  'holds(adjacent(x146, x147),0).',
#  'holds(adjacent(x146, x145),0).',
#  'holds(adjacent(x147, x1147),0).',
#  'holds(adjacent(x147, x148),0).',
#  'holds(adjacent(x147, x146),0).',
#  'holds(adjacent(x148, x1148),0).',
#  'holds(adjacent(x148, x149),0).',
#  'holds(adjacent(x148, x147),0).',
#  'holds(adjacent(x149, x1149),0).',
#  'holds(adjacent(x149, x150),0).',
#  'holds(adjacent(x149, x148),0).',
#  'holds(adjacent(x150, x1150),0).',
#  'holds(adjacent(x150, x151),0).',
#  'holds(adjacent(x150, x149),0).',
#  'holds(adjacent(x151, x1151),0).',
#  'holds(adjacent(x151, x152),0).',
#  'holds(adjacent(x151, x150),0).',
#  'holds(adjacent(x152, x1152),0).',
#  'holds(adjacent(x152, x153),0).',
#  'holds(adjacent(x152, x151),0).',
#  'holds(adjacent(x153, x1153),0).',
#  'holds(adjacent(x153, x154),0).',
#  'holds(adjacent(x153, x152),0).',
#  'holds(adjacent(x154, x1154),0).',
#  'holds(adjacent(x154, x155),0).',
#  'holds(adjacent(x154, x153),0).',
#  'holds(adjacent(x155, x1155),0).',
#  'holds(adjacent(x155, x156),0).',
#  'holds(adjacent(x155, x154),0).',
#  'holds(adjacent(x156, x1156),0).',
#  'holds(adjacent(x156, x157),0).',
#  'holds(adjacent(x156, x155),0).',
#  'holds(adjacent(x157, x1157),0).',
#  'holds(adjacent(x157, x158),0).',
#  'holds(adjacent(x157, x156),0).',
#  'holds(adjacent(x158, x1158),0).',
#  'holds(adjacent(x158, x159),0).',
#  'holds(adjacent(x158, x157),0).',
#  'holds(adjacent(x159, x1159),0).',
#  'holds(adjacent(x159, x160),0).',
#  'holds(adjacent(x159, x158),0).',
#  'holds(adjacent(x160, x1160),0).',
#  'holds(adjacent(x160, x161),0).',
#  'holds(adjacent(x160, x159),0).',
#  'holds(adjacent(x161, x1161),0).',
#  'holds(adjacent(x161, x162),0).',
#  'holds(adjacent(x161, x160),0).',
#  'holds(adjacent(x162, x1162),0).',
#  'holds(adjacent(x162, x163),0).',
#  'holds(adjacent(x162, x161),0).',
#  'holds(adjacent(x163, x1163),0).',
#  'holds(adjacent(x163, x164),0).',
#  'holds(adjacent(x163, x162),0).',
#  'holds(adjacent(x164, x1164),0).',
#  'holds(adjacent(x164, x165),0).',
#  'holds(adjacent(x164, x163),0).',
#  'holds(adjacent(x165, x1165),0).',
#  'holds(adjacent(x165, x166),0).',
#  'holds(adjacent(x165, x164),0).',
#  'holds(adjacent(x166, x1166),0).',
#  'holds(adjacent(x166, x167),0).',
#  'holds(adjacent(x166, x165),0).',
#  'holds(adjacent(x167, x1167),0).',
#  'holds(adjacent(x167, x168),0).',
#  'holds(adjacent(x167, x166),0).',
#  'holds(adjacent(x168, x1168),0).',
#  'holds(adjacent(x168, x169),0).',
#  'holds(adjacent(x168, x167),0).',
#  'holds(adjacent(x169, x1169),0).',
#  'holds(adjacent(x169, x170),0).',
#  'holds(adjacent(x169, x168),0).',
#  'holds(adjacent(x170, x1170),0).',
#  'holds(adjacent(x170, x171),0).',
#  'holds(adjacent(x170, x169),0).',
#  'holds(adjacent(x171, x1171),0).',
#  'holds(adjacent(x171, x172),0).',
#  'holds(adjacent(x171, x170),0).',
#  'holds(adjacent(x172, x1172),0).',
#  'holds(adjacent(x172, x173),0).',
#  'holds(adjacent(x172, x171),0).',
#  'holds(adjacent(x173, x1173),0).',
#  'holds(adjacent(x173, x174),0).',
#  'holds(adjacent(x173, x172),0).',
#  'holds(adjacent(x174, x1174),0).',
#  'holds(adjacent(x174, x175),0).',
#  'holds(adjacent(x174, x173),0).',
#  'holds(adjacent(x175, x1175),0).',
#  'holds(adjacent(x175, x176),0).',
#  'holds(adjacent(x175, x174),0).',
#  'holds(adjacent(x176, x1176),0).',
#  'holds(adjacent(x176, x177),0).',
#  'holds(adjacent(x176, x175),0).',
#  'holds(adjacent(x177, x1177),0).',
#  'holds(adjacent(x177, x178),0).',
#  'holds(adjacent(x177, x176),0).',
#  'holds(adjacent(x178, x1178),0).',
#  'holds(adjacent(x178, x179),0).',
#  'holds(adjacent(x178, x177),0).',
#  'holds(adjacent(x179, x1179),0).',
#  'holds(adjacent(x179, x180),0).',
#  'holds(adjacent(x179, x178),0).',
#  'holds(adjacent(x180, x1180),0).',
#  'holds(adjacent(x180, x181),0).',
#  'holds(adjacent(x180, x179),0).',
#  'holds(adjacent(x181, x1181),0).',
#  'holds(adjacent(x181, x182),0).',
#  'holds(adjacent(x181, x180),0).',
#  'holds(adjacent(x182, x1182),0).',
#  'holds(adjacent(x182, x183),0).',
#  'holds(adjacent(x182, x181),0).',
#  'holds(adjacent(x183, x1183),0).',
#  'holds(adjacent(x183, x184),0).',
#  'holds(adjacent(x183, x182),0).',
#  'holds(adjacent(x184, x1184),0).',
#  'holds(adjacent(x184, x185),0).',
#  'holds(adjacent(x184, x183),0).',
#  'holds(adjacent(x185, x1185),0).',
#  'holds(adjacent(x185, x186),0).',
#  'holds(adjacent(x185, x184),0).',
#  'holds(adjacent(x186, x1186),0).',
#  'holds(adjacent(x186, x187),0).',
#  'holds(adjacent(x186, x185),0).',
#  'holds(adjacent(x187, x1187),0).',
#  'holds(adjacent(x187, x188),0).',
#  'holds(adjacent(x187, x186),0).',
#  'holds(adjacent(x188, x1188),0).',
#  'holds(adjacent(x188, x189),0).',
#  'holds(adjacent(x188, x187),0).',
#  'holds(adjacent(x189, x1189),0).',
#  'holds(adjacent(x189, x190),0).',
#  'holds(adjacent(x189, x188),0).',
#  'holds(adjacent(x190, x1190),0).',
#  'holds(adjacent(x190, x191),0).',
#  'holds(adjacent(x190, x189),0).',
#  'holds(adjacent(x191, x1191),0).',
#  'holds(adjacent(x191, x192),0).',
#  'holds(adjacent(x191, x190),0).',
#  'holds(adjacent(x192, x1192),0).',
#  'holds(adjacent(x192, x193),0).',
#  'holds(adjacent(x192, x191),0).',
#  'holds(adjacent(x193, x1193),0).',
#  'holds(adjacent(x193, x194),0).',
#  'holds(adjacent(x193, x192),0).',
#  'holds(adjacent(x194, x1194),0).',
#  'holds(adjacent(x194, x195),0).',
#  'holds(adjacent(x194, x193),0).',
#  'holds(adjacent(x195, x1195),0).',
#  'holds(adjacent(x195, x196),0).',
#  'holds(adjacent(x195, x194),0).',
#  'holds(adjacent(x196, x1196),0).',
#  'holds(adjacent(x196, x197),0).',
#  'holds(adjacent(x196, x195),0).',
#  'holds(adjacent(x197, x1197),0).',
#  'holds(adjacent(x197, x198),0).',
#  'holds(adjacent(x197, x196),0).',
#  'holds(adjacent(x198, x1198),0).',
#  'holds(adjacent(x198, x199),0).',
#  'holds(adjacent(x198, x197),0).',
#  'holds(adjacent(x199, x1199),0).',
#  'holds(adjacent(x199, x200),0).',
#  'holds(adjacent(x199, x198),0).',
#  'holds(adjacent(x200, x1200),0).',
#  'holds(adjacent(x200, x201),0).',
#  'holds(adjacent(x200, x199),0).',
#  'holds(adjacent(x201, x1201),0).',
#  'holds(adjacent(x201, x202),0).',
#  'holds(adjacent(x201, x200),0).',
#  'holds(adjacent(x202, x1202),0).',
#  'holds(adjacent(x202, x203),0).',
#  'holds(adjacent(x202, x201),0).',
#  'holds(adjacent(x203, x1203),0).',
#  'holds(adjacent(x203, x204),0).',
#  'holds(adjacent(x203, x202),0).',
#  'holds(adjacent(x204, x1204),0).',
#  'holds(adjacent(x204, x205),0).',
#  'holds(adjacent(x204, x203),0).',
#  'holds(adjacent(x205, x1205),0).',
#  'holds(adjacent(x205, x206),0).',
#  'holds(adjacent(x205, x204),0).',
#  'holds(adjacent(x206, x1206),0).',
#  'holds(adjacent(x206, x207),0).',
#  'holds(adjacent(x206, x205),0).',
#  'holds(adjacent(x207, x1207),0).',
#  'holds(adjacent(x207, x208),0).',
#  'holds(adjacent(x207, x206),0).',
#  'holds(adjacent(x208, x1208),0).',
#  'holds(adjacent(x208, x209),0).',
#  'holds(adjacent(x208, x207),0).',
#  'holds(adjacent(x209, x1209),0).',
#  'holds(adjacent(x209, x210),0).',
#  'holds(adjacent(x209, x208),0).',
#  'holds(adjacent(x210, x1210),0).',
#  'holds(adjacent(x210, x211),0).',
#  'holds(adjacent(x210, x209),0).',
#  'holds(adjacent(x211, x1211),0).',
#  'holds(adjacent(x211, x212),0).',
#  'holds(adjacent(x211, x210),0).',
#  'holds(adjacent(x212, x1212),0).',
#  'holds(adjacent(x212, x213),0).',
#  'holds(adjacent(x212, x211),0).',
#  'holds(adjacent(x213, x1213),0).',
#  'holds(adjacent(x213, x214),0).',
#  'holds(adjacent(x213, x212),0).',
#  'holds(adjacent(x214, x1214),0).',
#  'holds(adjacent(x214, x215),0).',
#  'holds(adjacent(x214, x213),0).',
#  'holds(adjacent(x215, x1215),0).',
#  'holds(adjacent(x215, x216),0).',
#  'holds(adjacent(x215, x214),0).',
#  'holds(adjacent(x216, x1216),0).',
#  'holds(adjacent(x216, x217),0).',
#  'holds(adjacent(x216, x215),0).',
#  'holds(adjacent(x217, x1217),0).',
#  'holds(adjacent(x217, x218),0).',
#  'holds(adjacent(x217, x216),0).',
#  'holds(adjacent(x218, x1218),0).',
#  'holds(adjacent(x218, x219),0).',
#  'holds(adjacent(x218, x217),0).',
#  'holds(adjacent(x219, x1219),0).',
#  'holds(adjacent(x219, x220),0).',
#  'holds(adjacent(x219, x218),0).',
#  'holds(adjacent(x220, x1220),0).',
#  'holds(adjacent(x220, x221),0).',
#  'holds(adjacent(x220, x219),0).',
#  'holds(adjacent(x221, x1221),0).',
#  'holds(adjacent(x221, x222),0).',
#  'holds(adjacent(x221, x220),0).',
#  'holds(adjacent(x222, x1222),0).',
#  'holds(adjacent(x222, x223),0).',
#  'holds(adjacent(x222, x221),0).',
#  'holds(adjacent(x223, x1223),0).',
#  'holds(adjacent(x223, x224),0).',
#  'holds(adjacent(x223, x222),0).',
#  'holds(adjacent(x224, x1224),0).',
#  'holds(adjacent(x224, x225),0).',
#  'holds(adjacent(x224, x223),0).',
#  'holds(adjacent(x225, x1225),0).',
#  'holds(adjacent(x225, x226),0).',
#  'holds(adjacent(x225, x224),0).',
#  'holds(adjacent(x226, x1226),0).',
#  'holds(adjacent(x226, x227),0).',
#  'holds(adjacent(x226, x225),0).',
#  'holds(adjacent(x227, x1227),0).',
#  'holds(adjacent(x227, x228),0).',
#  'holds(adjacent(x227, x226),0).',
#  'holds(adjacent(x228, x1228),0).',
#  'holds(adjacent(x228, x229),0).',
#  'holds(adjacent(x228, x227),0).',
#  'holds(adjacent(x229, x1229),0).',
#  'holds(adjacent(x229, x230),0).',
#  'holds(adjacent(x229, x228),0).',
#  'holds(adjacent(x230, x1230),0).',
#  'holds(adjacent(x230, x231),0).',
#  'holds(adjacent(x230, x229),0).',
#  'holds(adjacent(x231, x1231),0).',
#  'holds(adjacent(x231, x232),0).',
#  'holds(adjacent(x231, x230),0).',
#  'holds(adjacent(x232, x1232),0).',
#  'holds(adjacent(x232, x233),0).',
#  'holds(adjacent(x232, x231),0).',
#  'holds(adjacent(x233, x1233),0).',
#  'holds(adjacent(x233, x234),0).',
#  'holds(adjacent(x233, x232),0).',
#  'holds(adjacent(x234, x1234),0).',
#  'holds(adjacent(x234, x235),0).',
#  'holds(adjacent(x234, x233),0).',
#  'holds(adjacent(x235, x1235),0).',
#  'holds(adjacent(x235, x236),0).',
#  'holds(adjacent(x235, x234),0).',
#  'holds(adjacent(x236, x1236),0).',
#  'holds(adjacent(x236, x237),0).',
#  'holds(adjacent(x236, x235),0).',
#  'holds(adjacent(x237, x1237),0).',
#  'holds(adjacent(x237, x238),0).',
#  'holds(adjacent(x237, x236),0).',
#  'holds(adjacent(x238, x1238),0).',
#  'holds(adjacent(x238, x239),0).',
#  'holds(adjacent(x238, x237),0).',
#  'holds(adjacent(x239, x1239),0).',
#  'holds(adjacent(x239, x240),0).',
#  'holds(adjacent(x239, x238),0).',
#  'holds(adjacent(x240, x1240),0).',
#  'holds(adjacent(x240, x241),0).',
#  'holds(adjacent(x240, x239),0).',
#  'holds(adjacent(x241, x1241),0).',
#  'holds(adjacent(x241, x242),0).',
#  'holds(adjacent(x241, x240),0).',
#  'holds(adjacent(x242, x1242),0).',
#  'holds(adjacent(x242, x243),0).',
#  'holds(adjacent(x242, x241),0).',
#  'holds(adjacent(x243, x1243),0).',
#  'holds(adjacent(x243, x244),0).',
#  'holds(adjacent(x243, x242),0).',
#  'holds(adjacent(x244, x1244),0).',
#  'holds(adjacent(x244, x245),0).',
#  'holds(adjacent(x244, x243),0).',
#  'holds(adjacent(x245, x1245),0).',
#  'holds(adjacent(x245, x246),0).',
#  'holds(adjacent(x245, x244),0).',
#  'holds(adjacent(x246, x1246),0).',
#  'holds(adjacent(x246, x247),0).',
#  'holds(adjacent(x246, x245),0).',
#  'holds(adjacent(x247, x1247),0).',
#  'holds(adjacent(x247, x248),0).',
#  'holds(adjacent(x247, x246),0).',
#  'holds(adjacent(x248, x1248),0).',
#  'holds(adjacent(x248, x249),0).',
#  'holds(adjacent(x248, x247),0).',
#  'holds(adjacent(x249, x1249),0).',
#  'holds(adjacent(x249, x250),0).',
#  'holds(adjacent(x249, x248),0).',
#  'holds(adjacent(x250, x1250),0).',
#  'holds(adjacent(x250, x251),0).',
#  'holds(adjacent(x250, x249),0).',
#  'holds(adjacent(x251, x1251),0).',
#  'holds(adjacent(x251, x252),0).',
#  'holds(adjacent(x251, x250),0).',
#  'holds(adjacent(x252, x1252),0).',
#  'holds(adjacent(x252, x253),0).',
#  'holds(adjacent(x252, x251),0).',
#  'holds(adjacent(x253, x1253),0).',
#  'holds(adjacent(x253, x254),0).',
#  'holds(adjacent(x253, x252),0).',
#  'holds(adjacent(x254, x1254),0).',
#  'holds(adjacent(x254, x255),0).',
#  'holds(adjacent(x254, x253),0).',
#  'holds(adjacent(x255, x1255),0).',
#  'holds(adjacent(x255, x256),0).',
#  'holds(adjacent(x255, x254),0).',
#  'holds(adjacent(x256, x1256),0).',
#  'holds(adjacent(x256, x257),0).',
#  'holds(adjacent(x256, x255),0).',
#  'holds(adjacent(x257, x1257),0).',
#  'holds(adjacent(x257, x258),0).',
#  'holds(adjacent(x257, x256),0).',
#  'holds(adjacent(x258, x1258),0).',
#  'holds(adjacent(x258, x259),0).',
#  'holds(adjacent(x258, x257),0).',
#  'holds(adjacent(x259, x1259),0).',
#  'holds(adjacent(x259, x260),0).',
#  'holds(adjacent(x259, x258),0).',
#  'holds(adjacent(x260, x1260),0).',
#  'holds(adjacent(x260, x261),0).',
#  'holds(adjacent(x260, x259),0).',
#  'holds(adjacent(x261, x1261),0).',
#  'holds(adjacent(x261, x262),0).',
#  'holds(adjacent(x261, x260),0).',
#  'holds(adjacent(x262, x1262),0).',
#  'holds(adjacent(x262, x263),0).',
#  'holds(adjacent(x262, x261),0).',
#  'holds(adjacent(x263, x1263),0).',
#  'holds(adjacent(x263, x264),0).',
#  'holds(adjacent(x263, x262),0).',
#  'holds(adjacent(x264, x1264),0).',
#  'holds(adjacent(x264, x265),0).',
#  'holds(adjacent(x264, x263),0).',
#  'holds(adjacent(x265, x1265),0).',
#  'holds(adjacent(x265, x266),0).',
#  'holds(adjacent(x265, x264),0).',
#  'holds(adjacent(x266, x1266),0).',
#  'holds(adjacent(x266, x267),0).',
#  'holds(adjacent(x266, x265),0).',
#  'holds(adjacent(x267, x1267),0).',
#  'holds(adjacent(x267, x268),0).',
#  'holds(adjacent(x267, x266),0).',
#  'holds(adjacent(x268, x1268),0).',
#  'holds(adjacent(x268, x269),0).',
#  'holds(adjacent(x268, x267),0).',
#  'holds(adjacent(x269, x1269),0).',
#  'holds(adjacent(x269, x270),0).',
#  'holds(adjacent(x269, x268),0).',
#  'holds(adjacent(x270, x1270),0).',
#  'holds(adjacent(x270, x271),0).',
#  'holds(adjacent(x270, x269),0).',
#  'holds(adjacent(x271, x1271),0).',
#  'holds(adjacent(x271, x272),0).',
#  'holds(adjacent(x271, x270),0).',
#  'holds(adjacent(x272, x1272),0).',
#  'holds(adjacent(x272, x273),0).',
#  'holds(adjacent(x272, x271),0).',
#  'holds(adjacent(x273, x1273),0).',
#  'holds(adjacent(x273, x274),0).',
#  'holds(adjacent(x273, x272),0).',
#  'holds(adjacent(x274, x1274),0).',
#  'holds(adjacent(x274, x275),0).',
#  'holds(adjacent(x274, x273),0).',
#  'holds(adjacent(x275, x1275),0).',
#  'holds(adjacent(x275, x276),0).',
#  'holds(adjacent(x275, x274),0).',
#  'holds(adjacent(x276, x1276),0).',
#  'holds(adjacent(x276, x277),0).',
#  'holds(adjacent(x276, x275),0).',
#  'holds(adjacent(x277, x1277),0).',
#  'holds(adjacent(x277, x278),0).',
#  'holds(adjacent(x277, x276),0).',
#  'holds(adjacent(x278, x1278),0).',
#  'holds(adjacent(x278, x279),0).',
#  'holds(adjacent(x278, x277),0).',
#  'holds(adjacent(x279, x1279),0).',
#  'holds(adjacent(x279, x280),0).',
#  'holds(adjacent(x279, x278),0).',
#  'holds(adjacent(x280, x1280),0).',
#  'holds(adjacent(x280, x281),0).',
#  'holds(adjacent(x280, x279),0).',
#  'holds(adjacent(x281, x1281),0).',
#  'holds(adjacent(x281, x282),0).',
#  'holds(adjacent(x281, x280),0).',
#  'holds(adjacent(x282, x1282),0).',
#  'holds(adjacent(x282, x283),0).',
#  'holds(adjacent(x282, x281),0).',
#  'holds(adjacent(x283, x1283),0).',
#  'holds(adjacent(x283, x284),0).',
#  'holds(adjacent(x283, x282),0).',
#  'holds(adjacent(x284, x1284),0).',
#  'holds(adjacent(x284, x285),0).',
#  'holds(adjacent(x284, x283),0).',
#  'holds(adjacent(x285, x1285),0).',
#  'holds(adjacent(x285, x286),0).',
#  'holds(adjacent(x285, x284),0).',
#  'holds(adjacent(x286, x1286),0).',
#  'holds(adjacent(x286, x287),0).',
#  'holds(adjacent(x286, x285),0).',
#  'holds(adjacent(x287, x1287),0).',
#  'holds(adjacent(x287, x288),0).',
#  'holds(adjacent(x287, x286),0).',
#  'holds(adjacent(x288, x1288),0).',
#  'holds(adjacent(x288, x289),0).',
#  'holds(adjacent(x288, x287),0).',
#  'holds(adjacent(x289, x1289),0).',
#  'holds(adjacent(x289, x290),0).',
#  'holds(adjacent(x289, x288),0).',
#  'holds(adjacent(x290, x1290),0).',
#  'holds(adjacent(x290, x291),0).',
#  'holds(adjacent(x290, x289),0).',
#  'holds(adjacent(x291, x1291),0).',
#  'holds(adjacent(x291, x292),0).',
#  'holds(adjacent(x291, x290),0).',
#  'holds(adjacent(x292, x1292),0).',
#  'holds(adjacent(x292, x293),0).',
#  'holds(adjacent(x292, x291),0).',
#  'holds(adjacent(x293, x1293),0).',
#  'holds(adjacent(x293, x294),0).',
#  'holds(adjacent(x293, x292),0).',
#  'holds(adjacent(x294, x1294),0).',
#  'holds(adjacent(x294, x295),0).',
#  'holds(adjacent(x294, x293),0).',
#  'holds(adjacent(x295, x1295),0).',
#  'holds(adjacent(x295, x296),0).',
#  'holds(adjacent(x295, x294),0).',
#  'holds(adjacent(x296, x1296),0).',
#  'holds(adjacent(x296, x297),0).',
#  'holds(adjacent(x296, x295),0).',
#  'holds(adjacent(x297, x1297),0).',
#  'holds(adjacent(x297, x298),0).',
#  'holds(adjacent(x297, x296),0).',
#  'holds(adjacent(x298, x1298),0).',
#  'holds(adjacent(x298, x299),0).',
#  'holds(adjacent(x298, x297),0).',
#  'holds(adjacent(x299, x1299),0).',
#  'holds(adjacent(x299, x300),0).',
#  'holds(adjacent(x299, x298),0).',
#  'holds(adjacent(x300, x1300),0).',
#  'holds(adjacent(x300, x301),0).',
#  'holds(adjacent(x300, x299),0).',
#  'holds(adjacent(x301, x1301),0).',
#  'holds(adjacent(x301, x302),0).',
#  'holds(adjacent(x301, x300),0).',
#  'holds(adjacent(x302, x1302),0).',
#  'holds(adjacent(x302, x303),0).',
#  'holds(adjacent(x302, x301),0).',
#  'holds(adjacent(x303, x1303),0).',
#  'holds(adjacent(x303, x304),0).',
#  'holds(adjacent(x303, x302),0).',
#  'holds(adjacent(x304, x1304),0).',
#  'holds(adjacent(x304, x305),0).',
#  'holds(adjacent(x304, x303),0).',
#  'holds(adjacent(x305, x1305),0).',
#  'holds(adjacent(x305, x306),0).',
#  'holds(adjacent(x305, x304),0).',
#  'holds(adjacent(x306, x1306),0).',
#  'holds(adjacent(x306, x307),0).',
#  'holds(adjacent(x306, x305),0).',
#  'holds(adjacent(x307, x1307),0).',
#  'holds(adjacent(x307, x308),0).',
#  'holds(adjacent(x307, x306),0).',
#  'holds(adjacent(x308, x1308),0).',
#  'holds(adjacent(x308, x309),0).',
#  'holds(adjacent(x308, x307),0).',
#  'holds(adjacent(x309, x1309),0).',
#  'holds(adjacent(x309, x310),0).',
#  'holds(adjacent(x309, x308),0).',
#  'holds(adjacent(x310, x1310),0).',
#  'holds(adjacent(x310, x311),0).',
#  'holds(adjacent(x310, x309),0).',
#  'holds(adjacent(x311, x1311),0).',
#  'holds(adjacent(x311, x312),0).',
#  'holds(adjacent(x311, x310),0).',
#  'holds(adjacent(x312, x1312),0).',
#  'holds(adjacent(x312, x313),0).',
#  'holds(adjacent(x312, x311),0).',
#  'holds(adjacent(x313, x1313),0).',
#  'holds(adjacent(x313, x314),0).',
#  'holds(adjacent(x313, x312),0).',
#  'holds(adjacent(x314, x1314),0).',
#  'holds(adjacent(x314, x315),0).',
#  'holds(adjacent(x314, x313),0).',
#  'holds(adjacent(x315, x1315),0).',
#  'holds(adjacent(x315, x316),0).',
#  'holds(adjacent(x315, x314),0).',
#  'holds(adjacent(x316, x1316),0).',
#  'holds(adjacent(x316, x317),0).',
#  'holds(adjacent(x316, x315),0).',
#  'holds(adjacent(x317, x1317),0).',
#  'holds(adjacent(x317, x318),0).',
#  'holds(adjacent(x317, x316),0).',
#  'holds(adjacent(x318, x1318),0).',
#  'holds(adjacent(x318, x319),0).',
#  'holds(adjacent(x318, x317),0).',
#  'holds(adjacent(x319, x1319),0).',
#  'holds(adjacent(x319, x320),0).',
#  'holds(adjacent(x319, x318),0).',
#  'holds(adjacent(x320, x1320),0).',
#  'holds(adjacent(x320, x321),0).',
#  'holds(adjacent(x320, x319),0).',
#  'holds(adjacent(x321, x1321),0).',
#  'holds(adjacent(x321, x322),0).',
#  'holds(adjacent(x321, x320),0).',
#  'holds(adjacent(x322, x1322),0).',
#  'holds(adjacent(x322, x323),0).',
#  'holds(adjacent(x322, x321),0).',
#  'holds(adjacent(x323, x1323),0).',
#  'holds(adjacent(x323, x324),0).',
#  'holds(adjacent(x323, x322),0).',
#  'holds(adjacent(x324, x1324),0).',
#  'holds(adjacent(x324, x325),0).',
#  'holds(adjacent(x324, x323),0).',
#  'holds(adjacent(x325, x1325),0).',
#  'holds(adjacent(x325, x326),0).',
#  'holds(adjacent(x325, x324),0).',
#  'holds(adjacent(x326, x1326),0).',
#  'holds(adjacent(x326, x327),0).',
#  'holds(adjacent(x326, x325),0).',
#  'holds(adjacent(x327, x1327),0).',
#  'holds(adjacent(x327, x328),0).',
#  'holds(adjacent(x327, x326),0).',
#  'holds(adjacent(x328, x1328),0).',
#  'holds(adjacent(x328, x329),0).',
#  'holds(adjacent(x328, x327),0).',
#  'holds(adjacent(x329, x1329),0).',
#  'holds(adjacent(x329, x330),0).',
#  'holds(adjacent(x329, x328),0).',
#  'holds(adjacent(x330, x1330),0).',
#  'holds(adjacent(x330, x331),0).',
#  'holds(adjacent(x330, x329),0).',
#  'holds(adjacent(x331, x1331),0).',
#  'holds(adjacent(x331, x332),0).',
#  'holds(adjacent(x331, x330),0).',
#  'holds(adjacent(x332, x1332),0).',
#  'holds(adjacent(x332, x333),0).',
#  'holds(adjacent(x332, x331),0).',
#  'holds(adjacent(x333, x1333),0).',
#  'holds(adjacent(x333, x334),0).',
#  ...]

# %%
np.random.randint(5)

# %%
a = 5

b = 3
def reee(c,b = c-1):
    print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-da9916c72ec4> in <module>
#       2
#       3 b = 3
# ----> 4 def reee(c,b = c-1):
#       5     print(b)
#
# NameError: name 'c' is not defined

# %%
reee(1)
# Out:
# 4

# %%
b = [1,4,2,4,2,4,23,4,2,5,7,8,6,5,3,4]
from random import shuffle
shuffle(b)

# %%
b
# Out:
# [2, 7, 4, 5, 3, 4, 4, 5, 4, 1, 4, 2, 23, 6, 2, 8]
